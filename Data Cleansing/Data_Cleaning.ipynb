# %% [markdown]
# <a href="https://colab.research.google.com/github/victoriaporter58/Airline-Sentiment-Analysis-using-Machine-Learning/blob/main/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cleaning and Preprocessing the Data

# %%
import pandas as pd
import nltk
from bs4 import BeautifulSoup
import string
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
df = pd.read_csv('Data Science TDA Group Project/Task2/Cleaning/Tweets2.csv')
df.shape
# Out:
# (14640, 15)

# %% [markdown]
# # Tokenize
# The breaks up the strings into a list of words.

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %%
df['text'] = df['text'].apply(lambda x: tokenizer.tokenize(x))
df['text'].head(20)
# Out:
# 0                 [VirginAmerica, What, dhepburn, said]
# 1     [VirginAmerica, plus, you, ve, added, commerci...
# 2     [VirginAmerica, I, didn, t, today, Must, mean,...
# 3     [VirginAmerica, it, s, really, aggressive, to,...
# 4     [VirginAmerica, and, it, s, a, really, big, ba...
# 5     [VirginAmerica, seriously, would, pay, 30, a, ...
# 6     [VirginAmerica, yes, nearly, every, time, I, f...
# 7     [VirginAmerica, Really, missed, a, prime, oppo...
# 8     [virginamerica, Well, I, didn, t, but, NOW, I,...
# 9     [VirginAmerica, it, was, amazing, and, arrived...
# 10    [VirginAmerica, did, you, know, that, suicide,...
# 11    [VirginAmerica, I, lt, 3, pretty, graphics, so...
# 12    [VirginAmerica, This, is, such, a, great, deal...
# 13    [VirginAmerica, virginmedia, I, m, flying, you...
# 14                              [VirginAmerica, Thanks]
# 15    [VirginAmerica, SFO, PDX, schedule, is, still,...
# 16    [VirginAmerica, So, excited, for, my, first, c...
# 17    [VirginAmerica, I, flew, from, NYC, to, SFO, l...
# 18                           [I, flying, VirginAmerica]
# 19    [VirginAmerica, you, know, what, would, be, am...
# Name: text, dtype: object

# %% [markdown]
# # Remove Stop Words
#
# These words have a low predictive power.

# %%
def remove_stopwords(text):
  words = [w for w in text if w not in stopwords.words('english')]
  return words

# %%
nltk.download('stopwords')
df['text'] = df['text'].apply(lambda x : remove_stopwords(x))
df['text'].head(10)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 0                [VirginAmerica, What, dhepburn, said]
# 1    [VirginAmerica, plus, added, commercials, expe...
# 2    [VirginAmerica, I, today, Must, mean, I, need,...
# 3    [VirginAmerica, really, aggressive, blast, obn...
# 4             [VirginAmerica, really, big, bad, thing]
# 5    [VirginAmerica, seriously, would, pay, 30, fli...
# 6    [VirginAmerica, yes, nearly, every, time, I, f...
# 7    [VirginAmerica, Really, missed, prime, opportu...
# 8              [virginamerica, Well, I, NOW, I, DO, D]
# 9    [VirginAmerica, amazing, arrived, hour, early,...
# Name: text, dtype: object

# %% [markdown]
# # Stemming & Lemmatizing
#
# Shorten words back to their root form.

# %%
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()

def word_lemmatizer(text):
  lem_text = [lemmatizer.lemmatize(i) for i in text]
  return lem_text
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
df['text'].apply(lambda x: word_lemmatizer(x))
# Out:
# 0                    [VirginAmerica, What, dhepburn, said]
# 1        [VirginAmerica, plus, added, commercial, exper...
# 2        [VirginAmerica, I, today, Must, mean, I, need,...
# 3        [VirginAmerica, really, aggressive, blast, obn...
# 4                 [VirginAmerica, really, big, bad, thing]
#                                ...
# 14635    [AmericanAir, thank, got, different, flight, C...
# 14636    [AmericanAir, leaving, 20, minute, Late, Fligh...
# 14637    [AmericanAir, Please, bring, American, Airline...
# 14638    [AmericanAir, money, change, flight, answer, p...
# 14639    [AmericanAir, 8, ppl, need, 2, know, many, sea...
# Name: text, Length: 14640, dtype: object

# %%
stemmer = PorterStemmer()

# %%
def word_stemmer(text):
  stem_text = " ".join([stemmer.stem(i) for i in text])
  return stem_text

# %%
df['text'] = df['text'].apply(lambda x : word_stemmer(x))

# %%
df['text']
# Out:
# 0                         virginamerica what dhepburn said
# 1               virginamerica plu ad commerci experi tacki
# 2        virginamerica I today must mean I need take an...
# 3        virginamerica realli aggress blast obnoxi ente...
# 4                       virginamerica realli big bad thing
#                                ...
# 14635          americanair thank got differ flight chicago
# 14636    americanair leav 20 minut late flight No warn ...
# 14637    americanair pleas bring american airlin blackb...
# 14638    americanair money chang flight answer phone an...
# 14639    americanair 8 ppl need 2 know mani seat next f...
# Name: text, Length: 14640, dtype: object

# %%
df.to_csv(r'/content/gdrive/My Drive/Data Science TDA Group Project/Task2/Cleaning/Cleaned.csv', index = False)

# %% [markdown]
# #Removing Data With Low Confidence

# %%
df = df.drop(df.query('airline_sentiment_confidence < 0.6').index)

# %%
df.to_csv(r'/content/gdrive/My Drive/Data Science TDA Group Project/Task2/Cleaning/CleanedSentimentAnalysis.csv', index = False)

# %%
df.shape
# Out:
# (14402, 15)

# %% [markdown]
# # Business Insights

# %%
wordDict = {}

counter = 0;
index = 0;



for y in df['airline_sentiment']:
  
  
  if y == 'negative':
    text = df.iloc[index,10]
    text = text.split()
    counter += 1 

    for i in range(len(text)):
      if text[i] in wordDict:
        wordDict[text[i]] += 1
      else:
        wordDict[text[i]] = 1
    
  
  index += 1
      

print(counter)
print(sorted(wordDict.items(), key=lambda x: x[1], reverse=True))
# Out:
# 9113
# [('I', 4315), ('flight', 3598), ('unit', 2876), ('usairway', 2365), ('americanair', 2105), ('southwestair', 1203), ('get', 1191), ('hour', 1100), ('jetblu', 1036), ('cancel', 925), ('delay', 914), ('custom', 781), ('servic', 777), ('time', 758), ('2', 733), ('help', 724), ('call', 701), ('wait', 669), ('bag', 663), ('hold', 653), ('plane', 597), ('amp', 501), ('still', 492), ('tri', 481), ('need', 476), ('flightl', 465), ('day', 451), ('one', 449), ('co', 447), ('http', 444), ('go', 442), ('gate', 424), ('fli', 409), ('phone', 397), ('airlin', 394), ('thank', 385), ('seat', 381), ('late', 378), ('back', 377), ('us', 376), ('would', 375), ('miss', 360), ('agent', 352), ('book', 346), ('3', 344), ('pleas', 328), ('make', 323), ('check', 322), ('chang', 319), ('minut', 315), ('you', 310), ('like', 306), ('4', 302), ('got', 298), ('min', 293), ('hr', 283), ('No', 283), ('never', 283), ('work', 279), ('today', 271), ('take', 270), ('1', 267), ('say', 264), ('even', 260), ('airport', 260), ('board', 259), ('guy', 253), ('connect', 253), ('5', 253), ('luggag', 247), ('ticket', 246), ('sit', 245), ('told', 244), ('want', 243), ('peopl', 243), ('issu', 243), ('worst', 240), ('realli', 235), ('problem', 235), ('last', 228), ('know', 228), ('rebook', 226), ('way', 226), ('weather', 225), ('travel', 222), ('lost', 221), ('anoth', 217), ('due', 212), ('what', 207), ('It', 207), ('w', 207), ('u', 203), ('email', 200), ('let', 200), ('ever', 200), ('someon', 197), ('can', 197), ('line', 195), ('baggag', 192), ('home', 192), ('not', 192), ('We', 191), ('virginamerica', 189), ('reserv', 185), ('thi', 184), ('use', 182), ('tell', 178), ('give', 177), ('tomorrow', 176), ('answer', 174), ('experi', 172), ('two', 171), ('number', 171), ('passeng', 171), ('the', 168), ('your', 167), ('could', 167), ('first', 162), ('onlin', 162), ('stuck', 160), ('pay', 158), ('respons', 158), ('bad', 157), ('whi', 157), ('said', 155), ('30', 154), ('look', 154), ('how', 153), ('crew', 152), ('system', 152), ('My', 152), ('leav', 151), ('sinc', 150), ('10', 150), ('arriv', 150), ('flightr', 149), ('refund', 147), ('next', 145), ('noth', 145), ('trip', 144), ('hotel', 143), ('good', 142), ('ye', 141), ('rude', 141), ('right', 140), ('hope', 140), ('week', 139), ('new', 139), ('fail', 137), ('websit', 137), ('see', 137), ('6', 136), ('find', 136), ('staff', 136), ('busi', 134), ('better', 134), ('now', 134), ('made', 133), ('long', 132), ('updat', 132), ('AA', 132), ('disappoint', 131), ('happen', 130), ('frustrat', 130), ('keep', 129), ('alreadi', 128), ('jfk', 127), ('come', 127), ('yet', 126), ('care', 126), ('ask', 124), ('put', 123), ('land', 122), ('mile', 120), ('left', 119), ('flt', 119), ('night', 117), ('just', 116), ('charg', 116), ('sure', 116), ('and', 115), ('think', 115), ('talk', 115), ('that', 114), ('fix', 113), ('person', 112), ('rep', 111), ('but', 109), ('they', 106), ('voucher', 106), ('attend', 106), ('terribl', 105), ('suck', 105), ('info', 104), ('ago', 103), ('speak', 103), ('anyon', 103), ('20', 102), ('option', 100), ('dfw', 100), ('credit', 99), ('avail', 98), ('anyth', 98), ('sent', 98), ('employe', 98), ('offer', 97), ('claim', 97), ('understand', 96), ('DM', 96), ('well', 96), ('air', 95), ('much', 95), ('8', 94), ('point', 94), ('pilot', 94), ('also', 93), ('wifi', 93), ('without', 93), ('US', 93), ('Is', 92), ('morn', 92), ('ridicul', 92), ('everi', 91), ('stop', 91), ('strand', 91), ('show', 91), ('A', 91), ('final', 91), ('tonight', 90), ('differ', 90), ('contact', 89), ('unaccept', 89), ('confirm', 89), ('suppos', 89), ('lax', 88), ('paid', 88), ('dca', 88), ('7', 88), ('delta', 87), ('thing', 86), ('hung', 86), ('seem', 85), ('yesterday', 85), ('receiv', 85), ('money', 85), ('almost', 84), ('upgrad', 83), ('phl', 83), ('extra', 82), ('poor', 82), ('great', 81), ('lose', 81), ('So', 81), ('send', 80), ('tarmac', 80), ('love', 79), ('app', 79), ('actual', 79), ('horribl', 79), ('fee', 78), ('year', 78), ('15', 78), ('ord', 78), ('s ...

# %%
wordDict = {}

counter = 0;
index = 0;



for y in df['airline_sentiment']:
  
  
  if y == 'negative':
    text = df.iloc[index,10]
    text = text.split()
    
    if 'custom' in text and 'servic' in text:
      

      counter += 1 
      for i in range(len(text)):
        if text[i] in wordDict:
          wordDict[text[i]] += 1
        else:
          wordDict[text[i]] = 1
    
  
  index += 1
      

print(counter)
print(sorted(wordDict.items(), key=lambda x: x[1], reverse=True))
# Out:
# 468
# [('custom', 490), ('servic', 487), ('I', 201), ('unit', 146), ('usairway', 144), ('flight', 103), ('americanair', 101), ('southwestair', 71), ('call', 54), ('worst', 52), ('hold', 49), ('hour', 40), ('get', 39), ('help', 36), ('ever', 36), ('phone', 35), ('terribl', 35), ('cancel', 33), ('jetblu', 32), ('wait', 32), ('poor', 30), ('line', 30), ('2', 30), ('airlin', 29), ('agent', 28), ('amp', 28), ('delay', 27), ('tri', 27), ('time', 23), ('today', 23), ('you', 22), ('rep', 22), ('never', 21), ('would', 21), ('still', 20), ('bag', 20), ('thank', 19), ('day', 19), ('No', 18), ('gate', 18), ('your', 18), ('rude', 18), ('min', 17), ('need', 17), ('experi', 17), ('minut', 17), ('guy', 16), ('lost', 16), ('one', 16), ('peopl', 16), ('bad', 16), ('flightl', 16), ('even', 15), ('know', 15), ('last', 15), ('fli', 15), ('http', 15), ('co', 15), ('horribl', 15), ('respons', 14), ('airport', 14), ('suck', 14), ('go', 13), ('speak', 13), ('like', 13), ('hr', 13), ('pleas', 13), ('staff', 13), ('what', 13), ('make', 13), ('person', 12), ('not', 12), ('4', 12), ('back', 12), ('care', 12), ('disappoint', 12), ('answer', 12), ('connect', 11), ('3', 11), ('way', 11), ('number', 11), ('talk', 11), ('book', 11), ('lack', 11), ('plane', 11), ('busi', 11), ('work', 11), ('1', 11), ('thi', 11), ('problem', 10), ('realli', 10), ('issu', 10), ('anoth', 10), ('provid', 10), ('hung', 10), ('miss', 10), ('sinc', 10), ('better', 9), ('complaint', 9), ('email', 9), ('take', 9), ('seat', 9), ('us', 9), ('due', 9), ('chang', 9), ('keep', 9), ('disconnect', 9), ('weather', 9), ('point', 9), ('travel', 8), ('luggag', 8), ('late', 8), ('experienc', 8), ('ye', 8), ('receiv', 8), ('week', 8), ('5', 8), ('the', 8), ('30', 8), ('say', 8), ('two', 8), ('w', 8), ('great', 8), ('delta', 8), ('got', 8), ('said', 7), ('want', 7), ('someon', 7), ('fix', 7), ('aw', 7), ('respond', 7), ('contact', 7), ('anyon', 7), ('happen', 7), ('give', 7), ('could', 7), ('employe', 7), ('let', 7), ('tell', 7), ('rebook', 7), ('noth', 7), ('they', 7), ('just', 7), ('nice', 7), ('websit', 7), ('also', 7), ('without', 7), ('desk', 7), ('been', 7), ('use', 7), ('hotel', 7), ('updat', 7), ('trip', 7), ('storm', 7), ('find', 7), ('yet', 7), ('fail', 7), ('40', 6), ('passeng', 6), ('long', 6), ('train', 6), ('ask', 6), ('real', 6), ('deal', 6), ('how', 6), ('think', 6), ('hang', 6), ('mile', 6), ('kid', 6), ('question', 6), ('and', 6), ('land', 6), ('can', 6), ('good', 6), ('attitud', 6), ('ago', 6), ('DM', 6), ('relat', 6), ('pay', 6), ('inform', 6), ('6', 6), ('reach', 6), ('alway', 6), ('first', 6), ('human', 5), ('So', 5), ('transfer', 5), ('compani', 5), ('ignor', 5), ('tweet', 5), ('that', 5), ('non', 5), ('crew', 5), ('disgust', 5), ('run', 5), ('sent', 5), ('stuck', 5), ('feel', 5), ('neveragain', 5), ('check', 5), ('mean', 5), ('info', 5), ('baggag', 5), ('final', 5), ('ticket', 5), ('sure', 5), ('new', 5), ('system', 5), ('continu', 5), ('zero', 5), ('lt', 5), ('bother', 5), ('via', 5), ('told', 5), ('right', 5), ('treat', 5), ('frustrat', 5), ('home', 5), ('phx', 5), ('AA', 5), ('virginamerica', 4), ('seem', 4), ('tix', 4), ('handl', 4), ('ur', 4), ('request', 4), ('atroci', 4), ('unitedairlin', 4), ('wors', 4), ('flightr', 4), ('unaccept', 4), ('abl', 4), ('confirm', 4), ('given', 4), ('lax', 4), ('strand', 4), ('joke', 4), ('100', 4), ('twice', 4), ('return', 4), ('attend', 4), ('15', 4), ('air', 4), ('hope', 4), ('allow', 4), ('there', 4), ('flightat', 4), ('love', 4), ('U', 4), ('On', 4), ('almost', 4), ('Do', 4), ('actual', 4), ('money', 4), ('absolut', 4), ('least', 4), ('whi', 4), ('differ', 4), ('spoke', 4), ('kind', 4), ('200', 4), ('veri', 4), ('fee', 4), ('futur', 4), ('11', 4), ('month', 4), ('basic', 4), ('upset', 4), ('mayb', 4), ('full', 4), ('repli', 4), ('flown', 4), ('year', 4), ('7', 4), ('voucher', 4), ('wow', 4), ('idea', 4), ('expect', 4), ('southwest', 4), ('sit', 4), ('refund', 4), ('badservic', 4), ('usual', 4), ('dealt', 4), ('anyth', 4), ('next', 4), ('fa ...

# %%
wordDict = {}

counter = 0;
index = 0;



for y in df['airline_sentiment']:
  
  
  if y == 'negative':
    text = df.iloc[index,10]
    text = text.split()
    
    if 'custom' in text and 'servic' in text:
      if 'hour' in text or 'wait' in text or 'hold' in text or 'time' in text or 'minut' in text or 'long' in text or 'call' in text:
      
        counter += 1 
        for i in range(len(text)):
          if text[i] in wordDict:
            wordDict[text[i]] += 1
          else:
            wordDict[text[i]] = 1
    
  
  index += 1
      

print(counter)
print(sorted(wordDict.items(), key=lambda x: x[1], reverse=True))
# Out:
# 149
# [('custom', 157), ('servic', 154), ('I', 77), ('call', 54), ('usairway', 50), ('hold', 49), ('hour', 40), ('flight', 37), ('unit', 33), ('wait', 32), ('southwestair', 31), ('americanair', 31), ('time', 23), ('line', 20), ('minut', 17), ('min', 15), ('cancel', 15), ('phone', 14), ('tri', 14), ('2', 14), ('help', 13), ('worst', 12), ('get', 12), ('terribl', 11), ('agent', 11), ('delay', 10), ('thank', 10), ('amp', 10), ('you', 10), ('back', 9), ('hr', 9), ('still', 8), ('suck', 8), ('flightl', 8), ('No', 8), ('bag', 7), ('rep', 7), ('peopl', 7), ('hung', 7), ('30', 7), ('speak', 7), ('1', 7), ('jetblu', 7), ('long', 6), ('not', 6), ('talk', 6), ('book', 6), ('plane', 6), ('today', 6), ('been', 6), ('disconnect', 6), ('got', 6), ('40', 5), ('3', 5), ('your', 5), ('5', 5), ('airlin', 5), ('busi', 5), ('need', 5), ('day', 5), ('rude', 5), ('say', 5), ('storm', 5), ('answer', 5), ('issu', 5), ('6', 5), ('pleas', 5), ('how', 5), ('keep', 5), ('sinc', 5), ('thi', 5), ('w', 5), ('connect', 4), ('late', 4), ('hang', 4), ('one', 4), ('last', 4), ('stuck', 4), ('air', 4), ('On', 4), ('without', 4), ('ever', 4), ('disappoint', 4), ('take', 4), ('tell', 4), ('go', 4), ('problem', 4), ('gate', 4), ('full', 4), ('way', 4), ('lost', 4), ('poor', 4), ('told', 4), ('find', 4), ('weather', 4), ('like', 3), ('4', 3), ('flightr', 3), ('noth', 3), ('fli', 3), ('there', 3), ('100', 3), ('two', 3), ('So', 3), ('neveragain', 3), ('websit', 3), ('want', 3), ('even', 3), ('respons', 3), ('work', 3), ('bad', 3), ('switch', 3), ('also', 3), ('could', 3), ('miss', 3), ('give', 3), ('rebook', 3), ('someon', 3), ('relat', 3), ('resolv', 3), ('us', 3), ('final', 3), ('and', 3), ('guy', 3), ('sit', 3), ('frustrat', 3), ('refund', 3), ('real', 3), ('human', 3), ('desk', 3), ('90', 3), ('1st', 3), ('My', 3), ('control', 3), ('the', 3), ('hotel', 3), ('b', 3), ('high', 3), ('volum', 3), ('virginamerica', 2), ('figur', 2), ('realli', 2), ('hire', 2), ('ask', 2), ('would', 2), ('anoth', 2), ('just', 2), ('flightat', 2), ('airport', 2), ('far', 2), ('2X', 2), ('team', 2), ('absolut', 2), ('shit', 2), ('supervisor', 2), ('tonight', 2), ('least', 2), ('done', 2), ('email', 2), ('200', 2), ('vacat', 2), ('system', 2), ('think', 2), ('staff', 2), ('luggag', 2), ('definit', 2), ('lack', 2), ('chang', 2), ('handl', 2), ('17', 2), ('wast', 2), ('offer', 2), ('DM', 2), ('hello', 2), ('allow', 2), ('ticket', 2), ('It', 2), ('delta', 2), ('transfer', 2), ('trip', 2), ('differ', 2), ('money', 2), ('http', 2), ('co', 2), ('right', 2), ('feel', 2), ('then', 2), ('signal', 2), ('Do', 2), ('what', 2), ('15', 2), ('idea', 2), ('treat', 2), ('takeoff', 2), ('never', 2), ('reach', 2), ('mon', 2), ('abl', 2), ('ago', 2), ('prompt', 2), ('half', 2), ('que', 2), ('plz', 2), ('badservic', 2), ('1hr', 2), ('experienc', 2), ('ye', 2), ('past', 2), ('mani', 2), ('know', 2), ('dalla', 2), ('can', 2), ('point', 2), ('11', 2), ('account', 2), ('If', 2), ('snack', 2), ('love', 2), ('mayb', 2), ('stop', 2), ('wrong', 2), ('info', 2), ('alway', 2), ('yet', 2), ('due', 2), ('fail', 2), ('nice', 2), ('8', 2), ('joke', 2), ('phx', 2), ('sorri', 2), ('pst', 2), ('hey', 2), ('12', 2), ('repres', 2), ('spoke', 2), ('manag', 2), ('reserv', 2), ('mechan', 2), ('clt', 2), ('cost', 2), ('morn', 2), ('might', 2), ('brush', 2), ('800', 2), ('serious', 2), ('non', 2), ('via', 2), ('AA', 2), ('crew', 2), ('care', 2), ('bc', 2), ('anyon', 2), ('let', 2), ('pay', 2), ('68', 2), ('35', 2), ('f', 2), ('drope', 2), ('basic', 2), ('horribl', 2), ('person', 2), ('new', 2), ('Is', 2), ('passeng', 1), ('seem', 1), ('va370', 1), ('stood', 1), ('inlin', 1), ('disgutedindenv', 1), ('awesom', 1), ('intent', 1), ('glad', 1), ('sent', 1), ('voicemail', 1), ('they', 1), ('extra', 1), ('50', 1), ('question', 1), ('rather', 1), ('As', 1), ('canada', 1), ('hope', 1), ('must', 1), ('den', 1), ('deal', 1), ('visibl', 1), ('60', 1), ('ea', 1), ('bk', 1), ('tix', 1), ('asia', 1), ('dont', 1), ('korea', 1), ('manilla', 1), ('experi',  ...
